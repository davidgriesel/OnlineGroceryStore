# %% [markdown]
# # Data Consistency Checks

# %% [markdown]
# # Contents
# 1. Import libraries
# 2. Import datasets
# 3. Check imported data
# 4. Consistency checks

# %% [markdown]
# # 1. Import libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Import datasets

# %%
#Define the project path
path = r'/Users/davidgriesel/Documents/0 - CareerFoundry/02 - Data Analytics Immersion/04 - Python Fundamentals for Data Analysts/Instacart Basket Analysis - IC 202409'

# %% [markdown]
# ## 2.1. Products

# %%
#Import dataset
df_products = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# ## 2.2. Orders

# %%
#Import dataset
df_orders = pd.read_csv(os.path.join(path, '02 - Data', 'Prepared Data', '04_orders_wrangled.csv'), index_col = 0)

# %% [markdown]
# # 3. Check imported data

# %% [markdown]
# ## 3.1. Products

# %%
# Get dimensions
df_products.shape
# Out:
# (49693, 5)

# %%
#View first 5 rows of the dataframe
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## 3.2. Orders

# %%
# Get dimensions
df_orders.shape
# Out:
# (3421083, 6)

# %%
#View first 5 rows of the dataframe
df_orders.head()
# Out:
#    order_id  user_id  user_order_number  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2398795        1                  2                   3
# 2    473747        1                  3                   3
# 3   2254736        1                  4                   4
# 4    431534        1                  5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# # 4. Consistency checks

# %% [markdown]
# ## 4.1. Products

# %% [markdown]
# ### 4.1.1. Accuracy

# %% [markdown]
# #### 4.1.1.1. View descriptive statistics

# %%
#Review descriptive statistics
df_products.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# ##### product_id: There are 49693 records but the max id is 49688 which suggest possible duplicates in the dataset.
# ##### aisle_id: All products are assigned to aisles. Aisles are numbered from 1 to 134.
# ##### department_id: All products are assinged to departments which are numbered 1 to 21.
# ##### prices: All products are priced. The average price is 9.99 and the median price is 7.10. The standard deviation is very large which suggests extreme outliers in the dataset. Most prices range between 4.10 and 11.20. The maximum price of 99999.00 is suspicious and likely en error.

# %% [markdown]
# #### 4.1.1.2. Find inaccurate values

# %%
#Display the frequency of unique values in the prices column
df_products['prices'].value_counts(dropna = True).sort_index(ascending = True)
# Out:
# prices
# 1.0        116
# 1.1        296
# 1.2        297
# 1.3        286
# 1.4        321
#           ...
# 24.8         5
# 24.9         6
# 25.0         5
# 14900.0      1
# 99999.0      1
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# ##### Identified two extreme outliers (14900.00 and 99999.00)

# %%
# Filter and display records where the price is either 14900 or 99999
df_products[df_products['prices'].isin([14900, 99999])]
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 21554       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
# 33666       33664             2 % Reduced Fat  Milk        84             16
#
#         prices
# 21554  14900.0
# 33666  99999.0

# %% [markdown]
# #### 4.1.1.3. Address inaccurate values

# %%
#Temporarily set pandas to display all rows
pd.set_option('display.max_rows', None)

# %%
#Filter for aisle_id == 108 and product_name contains 'cottage cheese'
df_products[(df_products['aisle_id'] == 108) & (df_products['product_name'].str.contains('cottage cheese', case=False, na=False))]
# Out:
#        product_id                                       product_name  \
# 194           195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 1503         1503                             Low Fat Cottage Cheese
# 2943         2943  Low Fat, Small Curd 1% Milkfat No Salt Added C...
# 3940         3940                              Nonfat Cottage Cheese
# 4991         4991                         Dairy Farms Cottage Cheese
# 5015         5015                     Organic Cottage Cheese Classic
# 6852         6852         4% Milkfat Cottage Cheese Small Curd 22 OZ
# 8285         8285                          Cottage Cheese Large Curd
# 8558         8558  Cottage Cheese, Natural Small Curd, 4% Milkfat...
# 9808         9808                             Organic Cottage Cheese
# 11109       11109      Organic 4% Milk Fat Whole Milk Cottage Cheese
# 11203       11203  Cottage Doubles Peach, 2% Milkfat Lowfat Cotta...
# 11259       11259                          2% Low-fat Cottage Cheese
# 11594       11594              Organic Cottage Cheese Kalamata Olive
# 11689       11689                   On the Go Low Fat Cottage Cheese
# 13083       13083                   Lowfat Small Curd Cottage Cheese
# 15122       15122            Organic Cottage Cheese Sun Dried Tomato
# 15285       15285                              Lowfat Cottage Cheese
# 16257       16257  2% Milkfat Low Fat Large Curd Pot Style Cottag...
# 16703       16703               4% Milkfat Large Curd Cottage Cheese
# 19460       19459                          Small Curd Cottage Cheese
# 19884       19883                       Small Curd Cottage Cheese 4%
# 21274       21273        Grade A Pasteurized Fat Free Cottage Cheese
# 21554       21553                   Lowfat 2% Milkfat Cottage Cheese
# 22130       22129                   1% Milkfat Lowfat Cottage Cheese
# 22731       22730                   Singles 1% Lowfat Cottage Cheese
# 25820       25819              Small Curd 4% Milk Fat Cottage Cheese
# 26442       26441                            Lf Cottage Cheese 16 Oz
# 27712       27710                 Fat Free Small Curd Cottage Cheese
# 27792       27790        Small Curd Lowfat 2% Milkfat Cottage Cheese
# 28422       28420         Organic Cultured Low Fat 1% Cottage Cheese
# 28478       28476                  Organic Small Curd Cottage Cheese
# 29128       29126   Organic Strawberry Chia Lowfat 2% Cottage Cheese
# 31032       31030               2% Milkfat Large Curd Cottage Cheese
# 32499       32497         Lowfat & Strawberry Topping Cottage Cheese
# 34232       34230               4% Milkfat Small Curd Cottage Cheese
# 35236       35234                          2% Low Fat Cottage Cheese
# 35448       35445                          Large Curd Cottage Cheese
# 35776       35772                           1% Lowfat Cottage Cheese
# 35951       35947   4% Milkfat Small Curd Cottage Cheese with Chives
# 36031       36027               Cottage Cheese Large Curd 4% Milkfat
# 36343       36339                                     Cottage Cheese
# 36365       36361         Organic Cottage Cheese Blueberry Acai Chia
# 37564       37560              4% Milkfat Small Curd  Cottage Cheese
# 38562       38558                     Organic Low Fat Cottage Cheese
# 38612       38608                           Lowfat Cottage Cheese 2%
# 38677       38673                           Pineapple Cottage Cheese
# 39435       39431                  Cottage Cheese 4% Milkfat Minimum
# 40450       40446                          1% Low Fat Cottage Cheese
# 41771       41767                               Cottage Cheese 22 Oz
# 42311       42307              Organic Reduced Fat 2% Cottage Cheese
# 45934       45930                  Small Curd Low Fat Cottage Cheese
# 46214       46210          4% Milkfat Min. Small Curd Cottage Cheese
# 46330       46326           Grade A Pasturized Lowfat Cottage Cheese
# 46791       46787                            Fat Free Cottage Cheese
# 47111       47107  4% Milkfat Small Curd Grade A Pasteurized Cott...
# 48263       48259         Non Fat Grade A Pasteurized Cottage Cheese
#
#        aisle_id  department_id   prices
# 194         108             16      3.3
# 1503        108             16      6.7
# 2943        108             16      2.2
# 3940        108             16      3.3
# 4991        108             16      6.8
# 5015        108             16      5.6
# 6852        108             16      8.6
# 8285        108             16     12.0
# 8558        108             16      2.7
# 9808        108             16      8.4
# 11109       108             16      2.0
# 11203       108             16      2.4
# 11259       108             16      9.4
# 11594       108             16     15.0
# 11689       108             16      5.8
# 13083       108             16      9.4
# 15122       108             16      3.8
# 15285       108             16      5.6
# 16257       108             16      5.3
# 16703       108             16      9.2
# 19460       108             16      1.3
# 19884       108             16      1.3
# 21274       108             16      6.5
# 21554       108             16  14900.0
# 22130       108             16      9.3
# 22731       108             16      2.2
# 25820       108             16      3.1
# 26442       108             16      9.6
# 27712       108             16      8.0
# 27792       108             16      7.7
# 28422       108             16     11.4
# 28478       108             16      8.2
# 29128       108             16      3.9
# 31032       108             16      7.2
# 32499       108             16      2.1
# 34232       108             16     11.5
# 35236       108             16      3.0
# 35448       108             16      6.5
# 35776       108             16      7.0
# 35951       108             16      6.1
# 36031       108             16      8.9
# 36343       108             16      4.7
# 36365       108             16      1.9
# 37564       108             16     11.6
# 38562       108             16     13.7
# 38612       108             16     10.5
# 38677       108             16     12.1
# 39435       108             16      1.1
# 40450       108             16      2.0
# 41771       108             16      1.6
# 42311       108             16      8.0
# 45934       108             16      8.4
# 46214       108             16      1.8
# 46330       108             16      9.7
# 46791       108             16      3.4
# 47111       108             16      6.4
# 48263       108             16      3.7

# %% [markdown]
# ##### In comparison to other simipar products from same aisle, the price is likely to be 14.9

# %%
#Filter for aisle_id == 84 and product_name contains 'milk'
# 13225        84             16      1.9
# 13249        84             16     12.1
# 13286        84             16      2.3
# 13568        84             16      7.8
# 13806        84             16      4.1
# 14023        84             16     12.6
# 14371        84             16      8.7
# 14882        84             16      8.4
# 14946        84             16     10.3
# 15142        84             16     13.9
# 15221        84             16      7.0
# 15789        84             16     14.1
# 16234        84             16      2.7
# 16425        84             16      8.8
# 16489        84             16     13.0
# 16611        84             16      7.3
# 16807        84             16     14.5
# 16939        84             16      5.4
# 17163        84             16      2.4
# 17316        84             16      2.9
# 17825        84             16      8.3
# 17871        84             16      5.3
# 17951        84             16     14.2
# 18175        84             16      6.0
# 18450        84             16      2.2
# 19009        84             16     11.8
# 19146        84             16      3.8
# 19156        84             16      5.9
# 19172        84             16      1.9
# 19349        84             16      4.6
# 19450        84             16     10.1
# 19585        84             16      1.7
# 19821        84             16     12.6
# 20083        84             16     11.1
# 20321        84             16      2.9
# 20464        84             16      2.7
# 20476        84             16      1.4
# 20744        84             16     12.5
# 20852        84             16      5.8
# 20941        84             16      5.4
# 21676        84             16     14.8
# 21867        84             16      4.6
# 21891        84             16     14.0
# 22038        84             16      3.2
# 22090        84             16      9.2
# 22124        84             16     14.7
# 22214        84             16      4.6
# 22326        84             16     12.7
# 22583        84             16     14.3
# 22671        84             16      8.8
# 22857        84             16      2.6
# 23083        84             16      3.5
# 23103        84             16      6.1
# 23384        84             16      7.2
# 23795        84             16      8.3
# 23910        84             16      9.2
# 23963        84             16      5.1
# 24025        84             16      9.6
# 24442        84             16      7.0
# 24522        84             16      4.2
# 24640        84             16      1.2
# 24892        84             16      4.4
# 25257        84             16      5.5
# 25261        84             16      5.4
# 25880        84             16      7.1
# 26136        84             16     15.0
# 26315        84             16      5.6
# 26347        84             16      9.3
# 26496        84             16      8.9
# 26896        84             16      2.9
# 26959        84             16      7.5
# 27272        84             16      8.4
# 27513        84             16      5.9
# 27847        84             16     12.8
# 28429        84             16     10.9
# 28522        84             16      1.7
# 28595        84             16      1.7
# 28791        84             16     14.0
# 29092        84             16     10.0
# 29378        84             16      3.0
# 29449        84             16     13.7
# 29573        84             16     10.1
# 29995        84             16     10.4
# 30379        84             16     13.6
# 31210        84             16     10.3
# 31427        84             16     14.6
# 31441        84             16      6.2
# 31520        84             16      8.6
# 31722        84             16      9.3
# 31983        84             16     13.7
# 32045        84             16      8.3
# 32110        84             16     12.7
# 32405        84             16      7.2
# 32422        84             16      5.9
# 32480        84             16     13.9
# 32568        84             16     10.7
# 32634        84             16      2.0
# 32749        84             16      1.6
# 33349        84             16     14.5
# 33383        84             16      2.0
# 33666        84             16  99999.0
# 33675        84             16      2.1
# 33804        84             16      7.5
# 34199        84             16      1.1
# 34259        84             16      1.5
# 34302        84             16     10.5
# 34596        84             16     14.0
# 34610        84             16      4.3
# 34704        84             16      6.3
# 34770        84             16      1.5
# 34868        84             16     10.3
# 35324        84             16      5.1
# 35374        84             16      7.0
# 35420        84             16     12.6
# 35917        84             16     12.2
# 35918        84             16      3.3
# 36015        84             16      3.2
# 36328        84             16      8.5
# 36933        84             16      5.4
# 36938        84             16     14.6
# 37651        84             16      6.5
# 37799        84             16     10.1
# 37870        84             16     10.7
# 37923        84             16     14.6
# 38457        84             16      1.8
# 38569        84             16      5.7
# 38693        84             16      8.8
# 38899        84             16     14.7
# 39184        84             16      2.1
# 39531        84             16      5.1
# 39706        84             16     10.5
# 39779        84             16     11.1
# 39838        84             16     10.3
# 39867        84             16      9.4
# 40039        84             16      5.7
# 40178        84             16     11.4
# 40187        84             16     14.3
# 40658        84             16      6.6
# 40695        84             16      4.4
# 41307        84             16     14.9
# 41492        84             16      9.2
# 41887        84             16      3.0
# 42009        84             16     12.8
# 42183        84             16     10.9
# 42447        84             16      6.9
# 42475        84             16      9.6
# 42483        84             16     13.6
# 42565        84             16      6.9
# 42566        84             16      5.7
# 43697        84             16     14.5
# 44397        84             16     10.7
# 45261        84             16     13.2
# 45283        84             16      8.8
# 45374        84             16     10.2
# 45442        84             16      1.2
# 45472        84             16      7.5
# 45508        84             16     14.3
# 45842        84             16      7.5
# 46007        84             16     10.6
# 46128        84             16     13.7
# 46150        84             16      2.9
# 46547        84             16      6.8
# 46678        84             16     14.8
# 47902        84             16     12.4
# 47959        84             16      5.7
# 48737        84             16      4.5
# 48850        84             16     10.6
# 48953        84             16     11.8
# 49030        84             16      1.4
# 49116        84             16      7.4
# 49416        84             16      1.4
# 49521        84             16     12.9
# 49553        84             16     11.9

# %% [markdown]
# ##### In comparison to other simipar products from same aisle, the price is likely to be 9.9

# %%
# Update the price from 14900 to 14.9
df_products.loc[df_products['prices'] == 14900, 'prices'] = 14.9

# Update the price from 99999 to 9.99
df_products.loc[df_products['prices'] == 99999, 'prices'] = 9.99

# %%
# Optionally reset the display option after displaying the DataFrame
pd.reset_option('display.max_rows')#Display the frequency of unique values in the prices column
df_products['prices'].value_counts(dropna = True).sort_index(ascending = True)
# Out:
# prices
# 1.0     116
# 1.1     296
# 1.2     297
# 1.3     286
# 1.4     321
#        ...
# 24.6      4
# 24.7      5
# 24.8      5
# 24.9      6
# 25.0      5
# Name: count, Length: 241, dtype: int64

# %% [markdown]
# ### 4.1.2. Missing values

# %% [markdown]
# #### 4.1.2.1. Find missing values

# %%
#Find missing values
df_products.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#Extract records where product_name is null and create subset with the results
df_products_nan = df_products[df_products['product_name']. isnull() == True]

# %%
#View subset
df_products_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# 38187       38183          NaN        39             12    20.9
# 40444       40440          NaN       120             16    14.8

# %% [markdown]
# #### 4.1.2.2. Address missing values

# %%
#Extract records where product_name is not null and update the dataframe with the results
df_products_clean = df_products[df_products['product_name']. isnull() == False]

# %%
#Get the dimensions of the updated dataframe
df_products_clean.shape
# Out:
# (49677, 5)

# %%
#Check results
49693 - 16
# Out:
# 49677

# %% [markdown]
# ### 4.1.3. Mixed-type data

# %% [markdown]
# #### 4.1.3.1. Find mixed-type data

# %%
#Finding mixed type data
for col in df_products_clean.columns.tolist():
    weird = (df_products_clean[[col]].map(type) != df_products_clean[[col]].iloc[0].apply(type)).any(axis=1)
    if len(df_products_clean[weird]) > 0:
        print (col)

# %%
#Return the data types of each column in the dataframe
df_products_clean.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# #### 4.1.3.2. Address mixed-type data

# %% [markdown]
# ##### No mixed-type data identified in the dataframe

# %% [markdown]
# ### 4.1.4. Duplicates

# %% [markdown]
# #### 4.1.4.1. Find duplicates

# %%
#Find duplicates and create subset with the results
df_products_duplicates = df_products_clean[df_products_clean.duplicated()]

# %%
#View subset
df_products_duplicates
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#Get the dimensions of the subset
df_products_duplicates.shape
# Out:
# (5, 5)

# %% [markdown]
# #### 4.1.4.2. Address duplicates

# %%
#Drop duplicates from new dataframe and update the dataframe with results
df_products_clean_no_duplicates = df_products_clean.drop_duplicates()

# %%
#Get the dimensions of the updated dataframe
df_products_clean_no_duplicates.shape
# Out:
# (49672, 5)

# %%
#Check results
49677 - 5
# Out:
# 49672

# %% [markdown]
# ## 4.2. Orders

# %% [markdown]
# ### 4.2.1. Accuracy

# %% [markdown]
# #### 4.2.1.1. View descriptive statistics

# %%
#Review descriptive statistics
df_orders.describe()
# Out:
#            order_id       user_id  user_order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06       3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05       1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04       1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00       1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04       5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05       1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05       2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05       1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# max         2.300000e+01            3.000000e+01

# %% [markdown]
# ##### order_id: Order id's range from 1 to 3421083 with a unique order id assigned sequentially to each record.
# ##### user_id: Customer id's range from 1 to 206209.
# ##### order_number: Users placed between 1 and 100 orders with an average of 11 orders per user.
# ##### orders_day_of_week: Orders are placed throughout the week, but more come in between Sunday and Thursday, with the slightly more being placed earlier in the week.
# ##### order_hour_of_day: Orders are placed throughout the day, but more come in between 10am and 4pm with most being placed in the early afternoon.
# ##### days_since_last_order: Users take between 0 and 30 days to place subsequent orders, with most taking about a week or slightly more to palce an order. Count for this column is 206209 less than the others. This is equal to the max for user_id.

# %% [markdown]
# ### 4.2.2. Missing values

# %% [markdown]
# #### 4.2.2.1. Find missing values

# %%
#Finding missing values
df_orders.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# user_order_number              0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
#View missing records
df_orders[df_orders['days_since_prior_order'].isnull() == True]
# Out:
#          order_id  user_id  user_order_number  orders_day_of_week  \
# 0         2539329        1                  1                   2
# 11        2168274        2                  1                   2
# 26        1374495        3                  1                   1
# 39        3343014        4                  1                   6
# 45        2717275        5                  1                   3
# ...           ...      ...                ...                 ...
# 3420930    969311   206205                  1                   4
# 3420934   3189322   206206                  1                   3
# 3421002   2166133   206207                  1                   6
# 3421019   2227043   206208                  1                   1
# 3421069   3154581   206209                  1                   3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 11                      11                     NaN
# 26                      14                     NaN
# 39                      11                     NaN
# 45                      12                     NaN
# ...                    ...                     ...
# 3420930                 12                     NaN
# 3420934                 18                     NaN
# 3421002                 19                     NaN
# 3421019                 15                     NaN
# 3421069                 11                     NaN
#
# [206209 rows x 6 columns]

# %% [markdown]
# ##### There are 206209 missing records in the 'days_since_last_order' column. View show 'order_number' is 1 for the top and bottom 5 records.

# %%
#View all records where order_number is 1 and days_since_last_order is null
df_orders[(df_orders['user_order_number'] == 1) & (df_orders['days_since_prior_order'].isnull() == True)]
# Out:
#          order_id  user_id  user_order_number  orders_day_of_week  \
# 0         2539329        1                  1                   2
# 11        2168274        2                  1                   2
# 26        1374495        3                  1                   1
# 39        3343014        4                  1                   6
# 45        2717275        5                  1                   3
# ...           ...      ...                ...                 ...
# 3420930    969311   206205                  1                   4
# 3420934   3189322   206206                  1                   3
# 3421002   2166133   206207                  1                   6
# 3421019   2227043   206208                  1                   1
# 3421069   3154581   206209                  1                   3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 11                      11                     NaN
# 26                      14                     NaN
# 39                      11                     NaN
# 45                      12                     NaN
# ...                    ...                     ...
# 3420930                 12                     NaN
# 3420934                 18                     NaN
# 3421002                 19                     NaN
# 3421019                 15                     NaN
# 3421069                 11                     NaN
#
# [206209 rows x 6 columns]

# %% [markdown]
# ##### Result contains 206209 records where 'order_number' is 1 and 'days_since_last_order' is null. This number agrees to the number of individual user_id's. Can conclude that the variable is null for each user's first order.

# %% [markdown]
# #### 4.2.2.2. Address missing values

# %%
#Copy the existing dataframe
df_orders_clean = df_orders.copy()

# %%
#Create a new column with boolean values
df_orders_clean['first_order'] = df_orders_clean['days_since_prior_order'].isna()

# %%
#View all records where order_number is 1 and days_since_last_order is null, and first_order is True
df_orders_clean[(df_orders_clean['user_order_number'] == 1) & (df_orders_clean['days_since_prior_order'].isnull() == True) & (df_orders_clean['first_order'] == True)]
# Out:
#          order_id  user_id  user_order_number  orders_day_of_week  \
# 0         2539329        1                  1                   2
# 11        2168274        2                  1                   2
# 26        1374495        3                  1                   1
# 39        3343014        4                  1                   6
# 45        2717275        5                  1                   3
# ...           ...      ...                ...                 ...
# 3420930    969311   206205                  1                   4
# 3420934   3189322   206206                  1                   3
# 3421002   2166133   206207                  1                   6
# 3421019   2227043   206208                  1                   1
# 3421069   3154581   206209                  1                   3
#
#          order_hour_of_day  days_since_prior_order  first_order
# 0                        8                     NaN         True
# 11                      11                     NaN         True
# 26                      14                     NaN         True
# 39                      11                     NaN         True
# 45                      12                     NaN         True
# ...                    ...                     ...          ...
# 3420930                 12                     NaN         True
# 3420934                 18                     NaN         True
# 3421002                 19                     NaN         True
# 3421019                 15                     NaN         True
# 3421069                 11                     NaN         True
#
# [206209 rows x 7 columns]

# %%
#Check frequency of flag column
df_orders_clean['first_order'].value_counts()
# Out:
# first_order
# False    3214874
# True      206209
# Name: count, dtype: int64

# %%
#Get dimensions
df_orders_clean.shape
# Out:
# (3421083, 7)

# %%
#View first 5 rows of the dataframe
df_orders_clean.head()
# Out:
#    order_id  user_id  user_order_number  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2398795        1                  2                   3
# 2    473747        1                  3                   3
# 3   2254736        1                  4                   4
# 4    431534        1                  5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order
# 0                  8                     NaN         True
# 1                  7                    15.0        False
# 2                 12                    21.0        False
# 3                  7                    29.0        False
# 4                 15                    28.0        False

# %% [markdown]
# ##### The null values are logical and deleting the column would result in the loss of valuable information. By creating a flag column, the null values are easily explained while maintaining the integrity of the original dataset

# %% [markdown]
# ### 4.2.3. Mixed-type data

# %% [markdown]
# #### 4.2.3.1. Find mixed-type data

# %%
#Finding mixed type data
for col in df_orders.columns.tolist():
    weird = (df_orders[[col]].map(type) != df_orders[[col]].iloc[0].apply(type)).any(axis=1)
    if len(df_orders[weird]) > 0:
        print (col)

# %%
#Return the data types of each column in the dataframe
df_orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# user_order_number           int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# #### 4.2.3.2. Address mixed-type data

# %% [markdown]
# ##### No mixed-type data identified in the dataframe

# %% [markdown]
# ### 4.2.4. Duplicates

# %% [markdown]
# #### 4.2.4.1. Find duplicates

# %%
#Find duplicates and create subset with the results
df_duplicate_orders = df_orders_clean[df_orders_clean.duplicated()]

# %%
#View results
df_duplicate_orders
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, user_order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, first_order]
# Index: []

# %% [markdown]
# #### 4.2.4.2. Address duplicates

# %% [markdown]
# ##### No duplicates were identified. Any duplicates must always be deleted.

# %% [markdown]
# # 5. Export dataframes

# %% [markdown]
# ## 5.1. Products

# %%
#Get the dimensions of the dataframe
df_products_clean_no_duplicates.shape
# Out:
# (49672, 5)

# %%
#Export cleaned products dataset
df_products_clean_no_duplicates.to_csv(os.path.join(path, '02 - Data', 'Prepared Data', '05_products_cleaned.csv'))

# %% [markdown]
# ## 5.2. Orders

# %%
#Get the dimensions of the dataframe
df_orders_clean.shape
# Out:
# (3421083, 7)

# %%
#Export cleaned orders dataset
df_orders_clean.to_csv(os.path.join(path, '02 - Data', 'Prepared Data', '05_orders_cleaned.csv'))

# %% [markdown]
# # Task

# %% [markdown]
# ## 1. Consistency checks
# If you haven’t performed the consistency checks covered in this Exercise on your df_prods dataframe, do so now.

# %% [markdown]
# ##### Refer: 4.1. Products

# %% [markdown]
# ## 2. Interpret descriptive statistics
# Run the df.describe() function on your df_ords dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.
# - Tip: Keep an eye on min and max values!

# %% [markdown]
# ##### Refer: 4.2.1.1. View descriptive statistics

# %% [markdown]
# ## 3. Find mixed-type data
# Check for mixed-type data in your df_ords dataframe.

# %% [markdown]
# ##### Refer: 4.2.3.1. Find mixed-type data

# %% [markdown]
# ## 4. Address mixed-type data
# If you find mixed-type data, fix it. The column in question should contain observations of a single data type.

# %% [markdown]
# ##### Refer: 4.2.3.2. Address mixed-type data

# %% [markdown]
# ## 5. Find missing values
# Run a check for missing values in your df_ords dataframe.
# - In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %% [markdown]
# ##### Refer: 4.2.2.1. Find missing values

# %% [markdown]
# ## 6. Address missing values
# Address the missing values using an appropriate method.
# - In a markdown cell, explain why you used your method of choice.

# %% [markdown]
# ##### Refer: 4.2.2.2. Address missing values

# %% [markdown]
# ## 7. Duplicates
# Run a check for duplicate values in your df_ords data.
# - In a markdown cell, report your findings and propose an explanation for any duplicate values you find.

# %% [markdown]
# ##### Refer: 4.2.4.1. Find duplicates

# %% [markdown]
# ## 8. Address duplicates
# Address the duplicates using an appropriate method.
# - In a markdown cell, explain why you used your method of choice.

# %% [markdown]
# ##### Refer: 4.2.4.2. Address duplicates

# %% [markdown]
# ## 9. Export dataframe
# Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder and give them appropriate, succinct names.

# %% [markdown]
# ##### Refer: 5. Export dataframes

# %% [markdown]
# ## 10. Save and submit notebook
# Save your Jupyter notebook and submit it here for your tutor to review.

# %% [markdown]
# ##### Notebook saved and submitted
